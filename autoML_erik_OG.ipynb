# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from autogluon.tabular import TabularPredictor
import autogluon

# %% [markdown]
# ## Define constans and functions

# %%
locations = ["A", "B", "C"]
features_order = []

LAGGED_COLUMNS_TO_KEEP = [
    # 'direct_rad:W_lag_1h', 
    'direct_rad:W_lag_forward_1h', 
    # 'clear_sky_rad:W_lag_1h', 
    'clear_sky_rad:W_lag_forward_1h', 
    # 'diffuse_rad:W_lag_1h', 
    'diffuse_rad:W_lag_forward_1h', 
    # 'direct_rad_1h:J_lag_1h', 
    'direct_rad_1h:J_lag_forward_1h', 
    # 'is_in_shadow:idx_lag_1h', 
    'is_in_shadow:idx_lag_forward_1h', 
    # 'clear_sky_energy_1h:J_lag_1h', 
    'clear_sky_energy_1h:J_lag_forward_1h', 
    # 'effective_cloud_cover:p_lag_1h', 
    'effective_cloud_cover:p_lag_forward_1h', 
    # 'visibility:m_lag_1h', 
    'visibility:m_lag_forward_1h', 
    # 'total_cloud_cover:p_lag_1h', 
    'total_cloud_cover:p_lag_forward_1h', 


    # 'direct_rad:W_lag_2h', 
    # 'direct_rad:W_lag_forward_2h', 
    # 'clear_sky_rad:W_lag_2h', 
    # 'clear_sky_rad:W_lag_forward_2h', 
    # 'diffuse_rad:W_lag_2h', 
    # 'diffuse_rad:W_lag_forward_2h', 
    # 'direct_rad_1h:J_lag_2h', 
    # 'direct_rad_1h:J_lag_forward_2h', 
    # 'is_in_shadow:idx_lag_2h', 
    # 'is_in_shadow:idx_lag_forward_2h', 
    # 'clear_sky_energy_1h:J_lag_2h', 
    # 'clear_sky_energy_1h:J_lag_forward_2h', 
    # 'effective_cloud_cover:p_lag_2h', 
    # 'effective_cloud_cover:p_lag_forward_2h', 
    # 'visibility:m_lag_2h', 
    # 'visibility:m_lag_forward_2h', 
    # 'total_cloud_cover:p_lag_2h', 
    # 'total_cloud_cover:p_lag_forward_2h', 

    # 'direct_rad:W_lag_3h', 
    # 'direct_rad:W_lag_forward_3h', 
    # 'clear_sky_rad:W_lag_3h', 
    # 'clear_sky_rad:W_lag_forward_3h', 
    # 'diffuse_rad:W_lag_3h', 
    # 'diffuse_rad:W_lag_forward_3h', 
    # 'direct_rad_1h:J_lag_3h', 
    # 'direct_rad_1h:J_lag_forward_3h', 
    # 'is_in_shadow:idx_lag_3h', 
    # 'is_in_shadow:idx_lag_forward_3h', 
    # 'clear_sky_energy_1h:J_lag_3h', 
    # 'clear_sky_energy_1h:J_lag_forward_3h', 
    # 'effective_cloud_cover:p_lag_3h', 
    # 'effective_cloud_cover:p_lag_forward_3h', 
    # 'visibility:m_lag_3h', 
    # 'visibility:m_lag_forward_3h', 
    # 'total_cloud_cover:p_lag_3h', 
    # 'total_cloud_cover:p_lag_forward_3h'
]

CUSTOM_COLUMNS_TO_KEEP = [
    "hour_cos",
    "hour_sin",
    "month_sin",
    "month_cos",
    "day-of-year",
    "hours_since_forecast"
]

WEATHER_FEATURES = [
    "direct_rad:W",
    "clear_sky_rad:W",
    "diffuse_rad:W",
    "direct_rad_1h:J",
    "is_in_shadow:idx",
    "clear_sky_energy_1h:J",
    "effective_cloud_cover:p",
    "visibility:m",
    "total_cloud_cover:p",
]


TEST_COLUMNS_TO_KEEP = [
    "direct_rad:W",
    "clear_sky_rad:W",
    "diffuse_rad:W",
    "direct_rad_1h:J",
    "is_in_shadow:idx",
    "clear_sky_energy_1h:J",
    "diffuse_rad_1h:J",
    "is_day:idx",
    "sun_elevation:d",
    "ceiling_height_agl:m",
    "effective_cloud_cover:p",
    "visibility:m",
    "total_cloud_cover:p",
    "air_density_2m:kgm3",
    "wind_speed_v_10m:ms",
    "dew_point_2m:K",
    "wind_speed_u_10m:ms",
    "t_1000hPa:K",
    "absolute_humidity_2m:gm3",
    "snow_water:kgm2",
    "relative_humidity_1000hPa:p",
    "fresh_snow_24h:cm",
    "cloud_base_agl:m",
    "fresh_snow_12h:cm",
    "snow_depth:cm",
    "dew_or_rime:idx",
    "fresh_snow_6h:cm",
    "super_cooled_liquid_water:kgm2",
    "fresh_snow_3h:cm",
    "rain_water:kgm2",
    "precip_type_5min:idx",
    "precip_5min:mm",
    "fresh_snow_1h:cm",
    "sun_azimuth:d",
    "msl_pressure:hPa",
    "pressure_100m:hPa",
    "pressure_50m:hPa",
    "sfc_pressure:hPa",
    "prob_rime:p",
    "wind_speed_10m:ms",
    # "elevation:m",
    # "snow_density:kgm3",
    # "snow_drift:idx",
    "snow_melt_10min:mm",
    "wind_speed_w_1000hPa:ms",
    "observed_or_estimated"
    # "location_A",
    # "location_B",
    # "location_C",
    # "date_calc",
] + CUSTOM_COLUMNS_TO_KEEP  +  LAGGED_COLUMNS_TO_KEEP

COLUMNS_TO_KEEP = TEST_COLUMNS_TO_KEEP + ["pv_measurement"]



def create_weather_lagged_features(df, weather_features):
    # Choose the weather features for which you want to create lagged versions
    for feature in weather_features:
        # Assuming hourly data, adjust the lags for your specific dataset
        # Creating lagged features for 1 hour, 1 day, and 1 week
        # df[f'{feature}_lag_1h'] = df[feature].shift(1)
        # df[f'{feature}_lag_2h'] = df[feature].shift(2)
        # df[f'{feature}_lag_3h'] = df[feature].shift(3)

        df[f'{feature}_lag_forward_1h'] = df[feature].shift(-1)
        # df[f'{feature}_lag_forward_2h'] = df[feature].shift(-2)
        # df[f'{feature}_lag_forward_3h'] = df[feature].shift(-3)
        # df[f'{feature}_lag_24h'] = df[feature].shift(24*4)
        # df[f'{feature}_lag_168h'] = df[feature].shift(24 * 7 * 4 * 365)
        # df[f'{feature}_front_lag_1h'] = df[feature].shift(-4)
        # df[f'{feature}_front_lag_24h'] = df[feature].shift(-24*4)


    # Handling edges by filling NaNs with appropriate values or dropping them
    # You may choose to fill with zeroes or interpolate, based on what makes more sense for your data
    # df.fillna(method='ffill', inplace=True)  # Forward fill  # Autogluon should handle this for us.
    # df.fillna(method='bfill', inplace=True)  # Backward fill  # Autogluon should handle this for us.
    
    return df


B_SCALE_VALUE = 6.3
C_SCALE_VALUE = 8.1

# %% [markdown]
# ## Prepare data

# %%
def add_custom_fields(df):
     df['hour_sin'] = np.sin(2 * np.pi * df['date_forecast'].dt.hour / 24)
     df['hour_cos'] = np.cos(2 * np.pi * df['date_forecast'].dt.hour / 24)

     df['month_sin'] = np.sin(2 * np.pi * df['date_forecast'].dt.month / 12)
     df['month_cos'] = np.cos(2 * np.pi * df['date_forecast'].dt.month / 12)
     df['day-of-year'] = df['date_forecast'].dt.dayofyear
     return df

def add_calc_date(df_observed, df_estimated, df_test):
    # Function to calculate the difference in hours
    def calculate_hour_difference(row):
        diff = row['date_calc'] - row['date_forecast']
        return diff.total_seconds() / 3600  # Convert difference to hours

    # Apply the function to calculate the hour difference for df_estimated and df_test
    df_estimated['hours_since_forecast'] = df_estimated.apply(calculate_hour_difference, axis=1)
    df_test['hours_since_forecast'] = df_test.apply(calculate_hour_difference, axis=1)

    # Fill in zero for df_observed
    df_observed['hours_since_forecast'] = 0

    return df_observed, df_estimated, df_test


def remove_outliers(df):
    # Use a mask to filter out the rows where rolling std is zero but keep the rows where the value itself is zero
    # Because some places in the data, the pv-measurements are messed up and are repeating.
    mask = (df['pv_measurement'].rolling(2).std() == 0) & (df['pv_measurement'] != 0)
    df[mask] = np.NaN  # Put this to NaN and hope autoGluon Handles.
    return df

def resample_add_data(df, is_test_data):
    df = add_custom_fields(df)
    df.set_index('date_forecast', inplace=True)
    df = df.resample('1H').mean()
    
    # Remove empty dates if test data
    if is_test_data:
        non_nan_threshold = len(df.columns) // 2
        df.dropna(thresh=non_nan_threshold, inplace=True)

    # df.interpolate(method="linear", inplace=True)  # Autogluon should handle this for us.
    
    return df

def add_location_feature(X, location):
      # Treat location as a categorical feature by converting it to a category type
    X['location'] = location
    X['location'] = X['location'].astype(str)  # Convert to string if 'location' is not an int
    # X['dew_or_rime:idx'] = X['dew_or_rime:idx'].astype(str)
    # X['is_day:idx'] = X['is_day:idx'].astype(str)
    # X['is_in_shadow:idx'] = X['is_in_shadow:idx'].astype(str)
    # categorical_columns = ['location', 'dew_or_rime:idx', 'is_day:idx', 'is_in_shadow:idx']

    # # Before filling NaN values, add 'missing' as a category for each categorical column.
    # for column in categorical_columns:
    #     X[column] = X[column].astype('category')  # Ensure the column is of type 'category'.
    #     if 'missing' not in X[column].cat.categories:
    #         X[column] = X[column].cat.add_categories(['missing'])  # Add 'missing' as a new category.
    #     X[column] = X[column].fillna('missing')
    # X['location'] = X['location'].astype('category')
    # X['dew_or_rime:idx'] = X['dew_or_rime:idx'].astype('category')
    # X['is_day:idx'] = X['is_day:idx'].astype('category')
    # X['is_in_shadow:idx'] = X['is_in_shadow:idx'].astype('category')
    
    return X

def add_scaling(X_test, X_training, location):
    global scalers
    continuous_columns = X_training.select_dtypes(include=['float32', 'int32']).columns
    if location not in scalers:
        scalers[location] = MinMaxScaler()
    X_training[continuous_columns] = scalers[location].fit_transform(X_training[continuous_columns])
    
    X_test[continuous_columns] = scalers[location].transform(X_test[continuous_columns])

    return X_test, X_training

# Skip this as we have hours since forecast as a feature.
# Deprecated as the concat is moved to main function.
def make_observed_and_estimated_category(df_observed, df_estimated, df_test):
     # Hot encode in wether observed or estimated
    df_observed['observed_or_estimated'] = 'observed'
    df_estimated['observed_or_estimated'] = 'estimated'
    df_test['observed_or_estimated'] = 'estimated'
    # Concatenate observed and estimated
    df_training = pd.concat([df_observed, df_estimated], axis=0).sort_values(by="date_forecast")
    df_training['observed_or_estimated'] = df_training['observed_or_estimated'].astype('category')
    df_test['observed_or_estimated'] = df_test['observed_or_estimated'].astype('category')

    return df_training, df_test

# %%
# Initialize a dictionary to hold the scalers for each location

scalers = {}


def prepare_data(location):
    # Load data
    scaling = False  # Set scaling to True to enable individual scaling for each location
    global scalers
    global scale_target 
    scale_target = False

    # Load training data
    df_observed = pd.read_parquet(f"data/{location}/X_train_observed.parquet")
    df_estimated = pd.read_parquet(f"data/{location}/X_train_estimated.parquet")
    df_target = pd.read_parquet(f"data/{location}/train_targets.parquet")
    # drop nan values in target data, pv measurement
    df_target.dropna(inplace=True)

   
    # Load test data
    df_test = pd.read_parquet(f"data/{location}/X_test_estimated.parquet")

   
    # Add calculated date
    df_observed, df_estimated, df_test = add_calc_date(df_observed, df_estimated, df_test)
    

    # Resample and add custom fields

    df_observed = resample_add_data(df_observed, False)
    df_estimated = resample_add_data(df_estimated, False)
    df_test = resample_add_data(df_test, True)

    df_training, df_test = make_observed_and_estimated_category(df_observed, df_estimated, df_test)
    

    # Autogluon should scale for us.
    if scale_target:
        if location == "B":
            df_target["pv_measurement"] = df_target["pv_measurement"] * B_SCALE_VALUE
        elif location == "C":
            df_target["pv_measurement"] = df_target["pv_measurement"] * C_SCALE_VALUE
    
    # Merge training with target data
    df_training = pd.merge(df_training, df_target, left_on="date_forecast", right_on="time", how="inner")
    
    # Create lagged features and remove outliers training
    df_training = create_weather_lagged_features(df_training, WEATHER_FEATURES)
    df_training = df_training[COLUMNS_TO_KEEP]
    df_training = remove_outliers(df_training)

    df_test = create_weather_lagged_features(df_test, WEATHER_FEATURES)
    df_test = df_test[TEST_COLUMNS_TO_KEEP]


    # Add categories
    df_training = add_location_feature(df_training, location)
    X_test = add_location_feature(df_test, location)
    
    # Add scaling
    if scaling:
        X_test, X_training = add_scaling(X_test, X_training, location)
    df_test.reset_index(inplace=True)
    df_test.drop(columns=["date_forecast"], inplace=True)
    # y_training = np.log1p(y_training)
    return df_training, X_test



# Use prepare_data function

combined_df_train = []
combined_df_test = []
combined_df_validation = []

for location in locations:
    # Prepare the training data
    X_training, X_test = prepare_data(location)

    df_training, df_test = prepare_data(location)
    # split df training at 
    X_training, X_validation = train_test_split(df_training[df_training["observed_or_estimated"] == "estimated"], test_size=1440, shuffle=True)
    X_training = pd.concat([X_training, df_training[df_training["observed_or_estimated"] == "observed"]])
    X_training = shuffle(X_training)
    
    combined_df_train.append(X_training)
    combined_df_validation.append(X_validation)

    combined_df_test.append(X_test)
# Out:
# <string>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8036\1072496628.py in ?()
#      76 combined_df_validation = []
#      77
#      78 for location in locations:
#      79     # Prepare the training data
# ---> 80     X_training, X_test = prepare_data(location)
#      81
#      82     df_training, df_test = prepare_data(location)
#      83     # split df training at
#
# ~\AppData\Local\Temp\ipykernel_8036\1072496628.py in ?(location)
#      56
#      57
#      58     # Add categories
#      59     df_training = add_location_feature(df_training, location)
# ---> 60     X_test = add_location_feature(df_test, location)
#      61
#      62     # Add scaling
#      63     if scaling:
#
# ~\AppData\Local\Temp\ipykernel_8036\2117605410.py in ?(X, location)
#      47 def add_location_feature(X, location):
#      48       # Treat location as a categorical feature by converting it to a category type
# ---> 49     X['location'] = location
#      50     X['location'] = X['location'].astype(str)  # Convert to string if 'location' is not an int
#      51     # X['dew_or_rime:idx'] = X['dew_or_rime:idx'].astype(str)
#      52     # X['is_day:idx'] = X['is_day:idx'].astype(str)
#
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4087             # Column to set is duplicated
#    4088             self._setitem_array([key], value)
#    4089         else:
#    4090             # set column
# -> 4091             self._set_item(key, value)
#
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4310                 if isinstance(existing_piece, DataFrame):
#    4311                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4312                     refs = None
#    4313
# -> 4314         self._set_item_mgr(key, value, refs)
#
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, key, value, refs)
#    4268         # check if we are modifying a copy
#    4269         # try to set first as we want an invalid
#    4270         # value exception to occur first
#    4271         if len(self):
# -> 4272             self._check_setitem_copy()
#
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, t, force)
#    4404                 "indexing.html#returning-a-view-versus-a-copy"
#    4405             )
#    4406
#    4407         if value == "raise":
# -> 4408             raise SettingWithCopyError(t)
#    4409         if value == "warn":
#    4410             warnings.warn(t, SettingWithCopyWarning, stacklevel=find_stack_level())
#
# SettingWithCopyError:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Define hyperparameters

# %%
# All of these hyperparameters have been found by experimenting with some standard parameters in AutoGluon, and then only using the best ones for each location to make the train time shorter
lgbmXT = {'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}
customlgbm = {'extra_trees': True, 'feature_fraction': 0.8, 'learning_rate': 0.02, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': 'custom2'}}

custom_fastai = {'bs': 1024, 'emb_drop': 0.6, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.008, 'ps': 0.09, 'ag_args': {'name_suffix': '_custom'}}

hyperparameters_a = {
    'NN_TORCH': {},
    'GBM': [lgbmXT, customlgbm, 'GBMLarge'],
    'FASTAI': [custom_fastai],
    'CAT': {},
}
hyperparameters_b_c = {
    'NN_TORCH': {},
    'GBM': [customlgbm],
    'KNN': [{'weights': 'uniform'}],
    'FASTAI': [{}, custom_fastai],
    'CAT': {},
}

# %% [markdown]
# ## Train

# %%
def train_model(dataset):
    # Define the path where the AutoGluon models will be saved
    # enumerate all the locations
    for index, location in enumerate(locations):
        save_path = f"autogluon_models/test_model{location}-Erik-2"

        if location == "A":
            hyperparameters = hyperparameters_a
        else:
            hyperparameters = hyperparameters_b_c

        # Initialize the TabularPredictor object
        model = TabularPredictor(
            label="pv_measurement", path=save_path, eval_metric="mae"
        )
        model.fit(
            train_data=combined_df_train[index].dropna(subset=["pv_measurement"]),
            tuning_data=combined_df_validation[index].dropna(subset=["pv_measurement"]),
            presets="experimental_zeroshot_hpo_hybrid",
            use_bag_holdout=True,
            hyperparameters=hyperparameters,
            # Got from the example in the docs
            # time_limit=60*60*2, # It did not use up the time
            num_bag_folds=2,
            num_bag_sets=2,
            num_stack_levels=1,
        )


def evaluate_model(X_val, y_val, location, model=None):
    if model is None:
        # If no model is passed, we assume the model has been previously saved and needs to be loaded
        save_path = f"autogluon_models_location_{location}"
        # model = TabularPredictor.load(save_path)
        model = autogluon.multimodal(save_path)

    # Predictions are made on the non-transformed validation data
    y_pred = model.predict(X_val)

    # If y_val was transformed (e.g., log1p), then apply the inverse transformation
    # y_val = np.expm1(y_val)
    # y_pred = np.expm1(y_pred)

    # Calculate the MAE
    mae = mean_absolute_error(y_val, y_pred)
    print(f"Location {location}, Mean Absolute Error: {mae}")


# Train the model using all available training data and the initial validation set for early stopping
train_model(combined_df_train)

# Evaluate the model using the same validation set
# evaluate_model(combined_X_val, combined_Y_val, location, model)
# Out:
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=2, num_bag_sets=2
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "autogluon_models/test_modelA"
# AutoGluon Version:  0.8.3b20231109
# Python Version:     3.11.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# Disk Space Avail:   274.56 GB / 511.10 GB (53.7%)
# Train Data Rows:    32643
# Train Data Columns: 59
# Tuning Data Rows:    1440
# Tuning Data Columns: 59
# Label Column: pv_measurement
# Preprocessing data ...
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5733.42, 0.0, 645.5171, 1177.59287)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:223: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7745.18 MB
# 	Train Data (Original)  Memory Usage: 10.6 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['location']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['observed_or_estimated']
# 		('float', [])    : 57 | ['direct_rad:W', 'clear_sky_rad:W', 'diffuse_rad:W', 'direct_rad_1h:J', 'is_in_shadow:idx', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 57 | ['direct_rad:W', 'clear_sky_rad:W', 'diffuse_rad:W', 'direct_rad_1h:J', 'is_in_shadow:idx', ...]
# 		('int', ['bool']) :  1 | ['observed_or_estimated']
# 	0.3s = Fit runtime
# 	58 features in original data used to generate 58 features in processed data.
# 	Train Data (Processed) Memory Usage: 8.62 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.39s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {'extra_trees': True, 'feature_fraction': 0.8, 'learning_rate': 0.02, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': 'custom2'}}, 'GBMLarge'],
# 	'FASTAI': [{'bs': 1024, 'emb_drop': 0.6, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.008, 'ps': 0.09, 'ag_args': {'name_suffix': '_custom'}}],
# 	'CAT': {},
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 6 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 4798.53s of the 7199.59s of remaining time.
# 2023-11-12 03:43:07,952	INFO util.py:159 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-89.6039	 = Validation score   (-mean_absolute_error)
# 	46.85s	 = Training   runtime
# 	29.02s	 = Validation runtime
# Fitting model: LightGBMcustom2_BAG_L1 ... Training model for up to 4687.36s of the 7088.43s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-86.3673	 = Validation score   (-mean_absolute_error)
# 	49.25s	 = Training   runtime
# 	29.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4612.84s of the 7013.9s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-97.8099	 = Validation score   (-mean_absolute_error)
# 	492.29s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L1 ... Training model for up to 4112.31s of the 6513.37s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-94.357	 = Validation score   (-mean_absolute_error)
# 	44.42s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4058.12s of the 6459.18s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-88.781	 = Validation score   (-mean_absolute_error)
# 	129.34s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3920.91s of the 6321.97s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-94.663	 = Validation score   (-mean_absolute_error)
# 	235.51s	 = Training   runtime
# 	64.37s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3633.04s of the 6034.1s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-87.7711	 = Validation score   (-mean_absolute_error)
# 	101.42s	 = Training   runtime
# 	66.19s	 = Validation runtime
# Fitting model: LightGBMcustom2_BAG_L1 ... Training model for up to 3545.49s of the 5946.55s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-85.4743	 = Validation score   (-mean_absolute_error)
# 	88.85s	 = Training   runtime
# 	56.9s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3479.53s of the 5880.59s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-96.2657	 = Validation score   (-mean_absolute_error)
# 	959.53s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L1 ... Training model for up to 3004.5s of the 5405.56s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-94.6311	 = Validation score   (-mean_absolute_error)
# 	86.32s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2953.83s of the 5354.89s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-86.565	 = Validation score   (-mean_absolute_error)
# 	246.16s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2825.67s of the 5226.74s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-95.0002	 = Validation score   (-mean_absolute_error)
# 	470.19s	 = Training   runtime
# 	130.73s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 479.85s of the 4934.38s of remaining time.
# 	-82.5296	 = Validation score   (-mean_absolute_error)
# 	0.33s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting 6 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4934.01s of the 4933.93s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-83.0302	 = Validation score   (-mean_absolute_error)
# 	4.49s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 4921.9s of the 4921.83s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-81.924	 = Validation score   (-mean_absolute_error)
# 	17.89s	 = Training   runtime
# 	2.7s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4890.76s of the 4890.68s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-85.6687	 = Validation score   (-mean_absolute_error)
# 	10.25s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 4872.68s of the 4872.58s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.02%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-85.3031	 = Validation score   (-mean_absolute_error)
# 	42.33s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 4821.99s of the 4821.9s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-80.4607	 = Validation score   (-mean_absolute_error)
# 	84.93s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 4728.53s of the 4728.44s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	-82.0316	 = Validation score   (-mean_absolute_error)
# 	13.61s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4706.69s of the 4706.61s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-83.3156	 = Validation score   (-mean_absolute_error)
# 	8.33s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 4694.79s of the 4694.71s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-81.7868	 = Validation score   (-mean_absolute_error)
# 	26.43s	 = Training   runtime
# 	3.78s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4677.11s of the 4677.02s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-85.5843	 = Validation score   (-mean_absolute_error)
# 	19.77s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 4659.64s of the 4659.55s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-85.5569	 = Validation score   (-mean_absolute_error)
# 	84.44s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 4608.99s of the 4608.9s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-79.2777	 = Validation score   (-mean_absolute_error)
# 	172.4s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 4512.94s of the 4512.86s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	-81.7225	 = Validation score   (-mean_absolute_error)
# 	27.44s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 493.4s of the 4490.35s of remaining time.
# 	-78.7728	 = Validation score   (-mean_absolute_error)
# 	0.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2710.43s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("autogluon_models/test_modelA")
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=2, num_bag_sets=2
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "autogluon_models/test_modelB"
# AutoGluon Version:  0.8.3b20231109
# Python Version:     3.11.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# Disk Space Avail:   273.74 GB / 511.10 GB (53.6%)
# Train Data Rows:    28151
# Train Data Columns: 59
# Tuning Data Rows:    1440
# Tuning Data Columns: 59
# Label Column: pv_measurement
# Preprocessing data ...
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1152.3, 0.0, 95.92685, 204.38803)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:223: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7241.17 MB
# 	Train Data (Original)  Memory Usage: 9.2 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['location']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['observed_or_estimated']
# 		('float', [])    : 57 | ['direct_rad:W', 'clear_sky_rad:W', 'diffuse_rad:W', 'direct_rad_1h:J', 'is_in_shadow:idx', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 57 | ['direct_rad:W', 'clear_sky_rad:W', 'diffuse_rad:W', 'direct_rad_1h:J', 'is_in_shadow:idx', ...]
# 		('int', ['bool']) :  1 | ['observed_or_estimated']
# 	0.4s = Fit runtime
# 	58 features in original data used to generate 58 features in processed data.
# 	Train Data (Processed) Memory Usage: 7.49 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.48s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'feature_fraction': 0.8, 'learning_rate': 0.02, 'min_data_in_leaf': 3, 'num_leaves': 21, 'ag_args': {'name_suffix': 'custom2'}}],
# 	'KNN': [{'weights': 'uniform'}],
# 	'FASTAI': [{}, {'bs': 1024, 'emb_drop': 0.6, 'epochs': 48, 'layers': [200, 100, 50], 'lr': 0.008, 'ps': 0.09, 'ag_args': {'name_suffix': '_custom'}}],
# 	'CAT': {},
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 6 L1 models ...
# Fitting model: KNeighbors_BAG_L1 ... Training model for up to 4798.48s of the 7199.51s of remaining time.
# 	-20.0961	 = Validation score   (-mean_absolute_error)
# 	0.12s	 = Training   runtime
# 	4.96s	 = Validation runtime
# Fitting model: LightGBMcustom2_BAG_L1 ... Training model for up to 4792.46s of the 7193.49s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-12.2726	 = Validation score   (-mean_absolute_error)
# 	39.36s	 = Training   runtime
# 	24.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4730.15s of the 7131.19s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-13.0377	 = Validation score   (-mean_absolute_error)
# 	459.67s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4262.45s of the 6663.49s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-14.758	 = Validation score   (-mean_absolute_error)
# 	48.65s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L1 ... Training model for up to 4206.31s of the 6607.34s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-14.5813	 = Validation score   (-mean_absolute_error)
# 	36.36s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4161.48s of the 6562.51s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-13.0503	 = Validation score   (-mean_absolute_error)
# 	138.76s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMcustom2_BAG_L1 ... Training model for up to 4014.32s of the 6415.35s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.9424	 = Validation score   (-mean_absolute_error)
# 	78.8s	 = Training   runtime
# 	47.95s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3950.28s of the 6351.31s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-12.9112	 = Validation score   (-mean_absolute_error)
# 	914.12s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3487.8s of the 5888.83s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-14.6494	 = Validation score   (-mean_absolute_error)
# 	99.52s	 = Training   runtime
# 	1.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L1 ... Training model for up to 3428.15s of the 5829.18s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-14.1939	 = Validation score   (-mean_absolute_error)
# 	73.14s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3382.75s of the 5783.78s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-12.8598	 = Validation score   (-mean_absolute_error)
# 	283.43s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 479.85s of the 5630.54s of remaining time.
# 	-11.6013	 = Validation score   (-mean_absolute_error)
# 	0.49s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 5 L2 models ...
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 5630.01s of the 5629.92s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.4148	 = Validation score   (-mean_absolute_error)
# 	48.98s	 = Training   runtime
# 	21.03s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5559.78s of the 5559.69s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.9123	 = Validation score   (-mean_absolute_error)
# 	16.96s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 5535.31s of the 5535.23s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-12.3613	 = Validation score   (-mean_absolute_error)
# 	51.44s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 5475.35s of the 5475.27s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-13.4302	 = Validation score   (-mean_absolute_error)
# 	37.21s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 5429.55s of the 5429.46s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.697	 = Validation score   (-mean_absolute_error)
# 	94.72s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 5326.39s of the 5326.3s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.3676	 = Validation score   (-mean_absolute_error)
# 	89.98s	 = Training   runtime
# 	32.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5266.75s of the 5266.67s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.7637	 = Validation score   (-mean_absolute_error)
# 	29.78s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 5246.1s of the 5246.01s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-12.0602	 = Validation score   (-mean_absolute_error)
# 	103.29s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 5185.25s of the 5185.16s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-13.4098	 = Validation score   (-mean_absolute_error)
# 	74.64s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 5139.07s of the 5138.98s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.7666	 = Validation score   (-mean_absolute_error)
# 	170.29s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 563.0s of the 5054.87s of remaining time.
# 	-11.158	 = Validation score   (-mean_absolute_error)
# 	0.97s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2146.19s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("autogluon_models/test_modelB")
# Presets specified: ['experimental_zeroshot_hpo_hybrid']
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=2, num_bag_sets=2
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to "autogluon_models/test_modelC"
# AutoGluon Version:  0.8.3b20231109
# Python Version:     3.11.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# Disk Space Avail:   273.50 GB / 511.10 GB (53.5%)
# Train Data Rows:    24195
# Train Data Columns: 59
# Tuning Data Rows:    1440
# Tuning Data Columns: 59
# Label Column: pv_measurement
# Preprocessing data ...
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\core\utils\utils.py:564: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (999.6, 0.0, 79.25137, 168.12162)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:215: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\learner\default_learner.py:223: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context("mode.use_inf_as_na", True):  # treat None, NaN, INF, NINF as NA
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7218.44 MB
# 	Train Data (Original)  Memory Usage: 7.97 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# ...
# 	32.41s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4173.36s of the 6574.45s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.00%)
# 	-11.6544	 = Validation score   (-mean_absolute_error)
# 	110.83s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMcustom2_BAG_L1 ... Training model for up to 4054.09s of the 6455.18s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-10.7321	 = Validation score   (-mean_absolute_error)
# 	77.96s	 = Training   runtime
# 	42.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3992.29s of the 6393.37s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-12.509	 = Validation score   (-mean_absolute_error)
# 	913.54s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3525.94s of the 5927.02s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-13.4549	 = Validation score   (-mean_absolute_error)
# 	91.08s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L1 ... Training model for up to 3471.83s of the 5872.91s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-13.0722	 = Validation score   (-mean_absolute_error)
# 	64.32s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3431.17s of the 5832.25s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.00%)
# 	-11.4236	 = Validation score   (-mean_absolute_error)
# 	246.07s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 479.86s of the 5688.49s of remaining time.
# 	-10.4012	 = Validation score   (-mean_absolute_error)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 5 L2 models ...
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 5687.93s of the 5687.84s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-10.0536	 = Validation score   (-mean_absolute_error)
# 	39.53s	 = Training   runtime
# 	20.89s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5626.92s of the 5626.84s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.3344	 = Validation score   (-mean_absolute_error)
# 	15.65s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 5603.19s of the 5603.09s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-10.8184	 = Validation score   (-mean_absolute_error)
# 	45.31s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 5549.55s of the 5549.46s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-11.0806	 = Validation score   (-mean_absolute_error)
# 	32.56s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 5508.44s of the 5508.36s of remaining time.
# 	Fitting 2 child models (S1F1 - S1F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-10.8873	 = Validation score   (-mean_absolute_error)
# 	78.33s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Repeating k-fold bagging: 2/2
# Fitting model: LightGBMcustom2_BAG_L2 ... Training model for up to 5421.45s of the 5421.37s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-9.9816	 = Validation score   (-mean_absolute_error)
# 	80.76s	 = Training   runtime
# 	42.02s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5356.92s of the 5356.84s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-11.3111	 = Validation score   (-mean_absolute_error)
# 	26.08s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 5338.54s of the 5338.46s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-10.7682	 = Validation score   (-mean_absolute_error)
# 	90.82s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_custom_BAG_L2 ... Training model for up to 5284.19s of the 5284.11s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	-11.0165	 = Validation score   (-mean_absolute_error)
# 	65.19s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 5242.98s of the 5242.9s of remaining time.
# 	Fitting 2 child models (S2F1 - S2F2) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	-10.705	 = Validation score   (-mean_absolute_error)
# 	165.68s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Completed 2/2 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 568.79s of the 5147.01s of remaining time.
# 	-9.924	 = Validation score   (-mean_absolute_error)
# 	0.77s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2053.83s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("autogluon_models/test_modelC")

# %%
print(leaderboard)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\autoML_erik_OG.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_erik_OG.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> print(leaderboard)
#
# NameError: name 'leaderboard' is not defined

# %% [markdown]
# # Feature importance

# %%
# model.leaderboard(combined_df_validation, silent=True)
# model.feature_importance(combined_df_validation, time_limit=120)

predictior = TabularPredictor.load(f"autogluon_models/test_modelA", require_version_match=False)


# Get the leaderboard
print("leaderboard")
leaderboard = predictior.leaderboard(silent=True)

# Retrieve the best model's name
best_model = leaderboard.iloc[0]['model']
print("Predictor info:")
predictior.info()

# # Retrieve hyperparameters of the best model
# best_model_info = predictior.get_model_info(model=best_model)
# best_hyperparameters = best_model_info['hyperparameters']

# # Optionally, save or print these hyperparameters
# print("Best Model Hyperparameters:", best_hyperparameters)
# Out:
# leaderboard
# Predictor info:
# {'path': 'autogluon_models/test_modelA',
#  'label': 'pv_measurement',
#  'random_state': 0,
#  'version': '0.8.3b20231109',
#  'features': ['direct_rad:W',
#   'clear_sky_rad:W',
#   'diffuse_rad:W',
#   'direct_rad_1h:J',
#   'is_in_shadow:idx',
#   'clear_sky_energy_1h:J',
#   'diffuse_rad_1h:J',
#   'is_day:idx',
#   'sun_elevation:d',
#   'ceiling_height_agl:m',
#   'effective_cloud_cover:p',
#   'visibility:m',
#   'total_cloud_cover:p',
#   'air_density_2m:kgm3',
#   'wind_speed_v_10m:ms',
#   'dew_point_2m:K',
#   'wind_speed_u_10m:ms',
#   't_1000hPa:K',
#   'absolute_humidity_2m:gm3',
#   'snow_water:kgm2',
#   'relative_humidity_1000hPa:p',
#   'fresh_snow_24h:cm',
#   'cloud_base_agl:m',
#   'fresh_snow_12h:cm',
#   'snow_depth:cm',
#   'dew_or_rime:idx',
#   'fresh_snow_6h:cm',
#   'super_cooled_liquid_water:kgm2',
#   'fresh_snow_3h:cm',
#   'rain_water:kgm2',
#   'precip_type_5min:idx',
#   'precip_5min:mm',
#   'fresh_snow_1h:cm',
#   'sun_azimuth:d',
#   'msl_pressure:hPa',
#   'pressure_100m:hPa',
#   'pressure_50m:hPa',
#   'sfc_pressure:hPa',
#   'prob_rime:p',
#   'wind_speed_10m:ms',
#   'snow_melt_10min:mm',
#   'wind_speed_w_1000hPa:ms',
#   'observed_or_estimated',
#   'hour_cos',
#   'hour_sin',
#   'month_sin',
#   'month_cos',
#   'day-of-year',
#   'hours_since_forecast',
#   'direct_rad:W_lag_forward_1h',
#   'clear_sky_rad:W_lag_forward_1h',
#   'diffuse_rad:W_lag_forward_1h',
#   'direct_rad_1h:J_lag_forward_1h',
#   'is_in_shadow:idx_lag_forward_1h',
#   'clear_sky_energy_1h:J_lag_forward_1h',
#   'effective_cloud_cover:p_lag_forward_1h',
#   'visibility:m_lag_forward_1h',
#   'total_cloud_cover:p_lag_forward_1h'],
#  'feature_metadata_in': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1bb5f98c750>,
#  'time_fit_preprocessing': 0.39427852630615234,
#  'time_fit_training': 2710.040125846863,
#  'time_fit_total': 2710.434404373169,
#  'time_limit': 7200,
#  'time_train_start': 1699756967.306808,
#  'num_rows_train': 32643,
#  'num_cols_train': 58,
#  'num_rows_val': 1440,
#  'num_classes': None,
#  'problem_type': 'regression',
#  'eval_metric': 'mean_absolute_error',
#  'best_model': 'WeightedEnsemble_L3',
#  'best_model_score_val': -78.7728039446139,
#  'best_model_stack_level': 3,
#  'num_models_trained': 14,
#  'num_bag_folds': 2,
#  'max_stack_level': 3,
#  'max_core_stack_level': 2,
#  'model_info': {'LightGBMXT_BAG_L1': {'name': 'LightGBMXT_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'regression',
#    'eval_metric': 'mean_absolute_error',
#    'stopping_metric': 'mean_absolute_error',
#    'fit_time': 101.42185068130493,
#    'num_classes': None,
#    'quantile_levels': None,
#    'predict_time': 66.18623566627502,
#    'val_score': -87.77111912794463,
#    'hyperparameters': {'use_orig_features': True,
#     'max_base_models': 25,
#     'max_base_models_per_type': 5,
#     'save_bag_folds': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 58,
#    'features': ['is_in_shadow:idx',
#     'snow_melt_10min:mm',
#     'dew_point_2m:K',
#     'cloud_base_agl:m',
#     'fresh_snow_3h:cm',
#     'fresh_snow_6h:cm',
#     'month_sin',
#     'clear_sky_energy_1h:J_lag_forward_1h',
#     'clear_sky_energy_1h:J',
#     'fresh_snow_24h:cm',
#     'month_cos',
#     'diffuse_rad:W_lag_forward_1h',
#     'air_density_2m:kgm3',
#     'msl_pressure:hPa',
#     'fresh_snow_1h:cm',
#     'direct_rad_1h:J_lag_forward_1h',
#     'snow_water:kgm2',
#     'direct_rad:W_lag_forward_1h',
#     'pressure_100m:hPa',
#     'is_in_shadow:idx_lag_forward_1h',
#     'diffuse_rad:W',
#     'sun_azimuth:d',
#     'fresh_snow_12h:cm',
#     'wind_speed_w_1000hPa:ms',
#     'pressure_50m:hPa',
#     'wind_speed_10m:ms',
#     'diffuse_rad_1h:J',
#     'absolute_humidity_2m:gm3',
#     'precip_type_5min:idx',
#     'precip_5min:mm',
#     'ceiling_height_agl:m',
#     'rain_water:kgm2',
#     'hour_cos',
#     'total_cloud_cover:p_lag_forward_1h',
#     'wind_speed_v_10m:ms',
#     'effective_cloud_cover:p',
#     'super_cooled_liquid_water:kgm2',
#     'day-of-year',
#     'is_day:idx',
#     'wind_speed_u_10m:ms',
#     't_1000hPa:K',
#     'relative_humidity_1000hPa:p',
#     'clear_sky_rad:W_lag_forward_1h',
#     'dew_or_rime:idx',
#     'sfc_pressure:hPa',
#     'snow_depth:cm',
#     'total_cloud_cover:p',
#     'visibility:m',
#     'effective_cloud_cover:p_lag_forward_1h',
#     'prob_rime:p',
#     'hours_since_forecast',
#     'direct_rad_1h:J',
#     'direct_rad:W',
#     'hour_sin',
#     'visibility:m_lag_forward_1h',
#     'sun_elevation:d',
#     'observed_or_estimated',
#     'clear_sky_rad:W'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1badc07a210>,
#    'memory_size': 4211,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'bagged_info': {'child_model_type': 'LGBModel',
#     'num_child_models': 4,
#     'child_model_names': ['S1F2', 'S1F1', 'S2F1', 'S2F2'],
#     '_n_repeats': 2,
#     '_k_per_n_repeat': [2, 2],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': True,
#     'max_memory_size': 109988934,
#     'min_memory_size': 27574325,
#     'child_hyperparameters': {'learning_rate': 0.05, 'extra_trees': True},
#     'child_hyperparameters_fit': {'num_boost_round': 9973},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F2': {'name': 'S1F2',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 43.45133185386658,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 14.326476097106934,
#      'val_score': -166.42643980867,
#      'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True},
#      'hyperparameters_fit': {'num_boost_round': 9988},
#      'hyperparameters_nondefault': ['extra_trees'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8444a790>,
#      'memory_size': 27534713,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S1F1': {'name': 'S1F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 46.85213851928711,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 14.69634222984314,
#      'val_score': -169.05668710678884,
#      'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True},
#      'hyperparameters_fit': {'num_boost_round': 9987},
#      'hyperparameters_nondefault': ['extra_trees'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba9cb714d0>,
#      'memory_size': 27540269,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F1': {'name': 'S2F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 53.441141843795776,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 18.405046701431274,
#      'val_score': -167.8635814913121,
#      'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True},
#      'hyperparameters_fit': {'num_boost_round': 9917},
#      'hyperparameters_nondefault': ['extra_trees'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba9cc42b50>,
#      'memory_size': 27339627,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F2': {'name': 'S2F2',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 54.51986813545227,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 18.758370637893677,
#      'val_score': -166.57615343173512,
#      'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True},
#      'hyperparameters_fit': {'num_boost_round': 10000},
#      'hyperparameters_nondefault': ['extra_trees'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba86541650>,
#      'memory_size': 27570114,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True}}},
#   'LightGBMcustom2_BAG_L1': {'name': 'LightGBMcustom2_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'regression',
#    'eval_metric': 'mean_absolute_error',
#    'stopping_metric': 'mean_absolute_error',
#    'fit_time': 88.84643268585205,
#    'num_classes': None,
#    'quantile_levels': None,
#    'predict_time': 56.898024797439575,
#    'val_score': -85.47425252628668,
#    'hyperparameters': {'use_orig_features': True,
#     'max_base_models': 25,
#     'max_base_models_per_type': 5,
#     'save_bag_folds': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 58,
#    'features': ['is_in_shadow:idx',
#     'snow_melt_10min:mm',
#     'dew_point_2m:K',
#     'cloud_base_agl:m',
#     'fresh_snow_3h:cm',
#     'fresh_snow_6h:cm',
#     'month_sin',
#     'clear_sky_energy_1h:J_lag_forward_1h',
#     'clear_sky_energy_1h:J',
#     'fresh_snow_24h:cm',
#     'month_cos',
#     'diffuse_rad:W_lag_forward_1h',
#     'air_density_2m:kgm3',
#     'msl_pressure:hPa',
#     'fresh_snow_1h:cm',
#     'direct_rad_1h:J_lag_forward_1h',
#     'snow_water:kgm2',
#     'direct_rad:W_lag_forward_1h',
#     'pressure_100m:hPa',
#     'is_in_shadow:idx_lag_forward_1h',
#     'diffuse_rad:W',
#     'sun_azimuth:d',
#     'fresh_snow_12h:cm',
#     'wind_speed_w_1000hPa:ms',
#     'pressure_50m:hPa',
#     'wind_speed_10m:ms',
#     'diffuse_rad_1h:J',
#     'absolute_humidity_2m:gm3',
#     'precip_type_5min:idx',
#     'precip_5min:mm',
#     'ceiling_height_agl:m',
#     'rain_water:kgm2',
#     'hour_cos',
#     'total_cloud_cover:p_lag_forward_1h',
#     'wind_speed_v_10m:ms',
#     'effective_cloud_cover:p',
#     'super_cooled_liquid_water:kgm2',
#     'day-of-year',
#     'is_day:idx',
#     'wind_speed_u_10m:ms',
#     't_1000hPa:K',
#     'relative_humidity_1000hPa:p',
#     'clear_sky_rad:W_lag_forward_1h',
#     'dew_or_rime:idx',
#     'sfc_pressure:hPa',
#     'snow_depth:cm',
#     'total_cloud_cover:p',
#     'visibility:m',
#     'effective_cloud_cover:p_lag_forward_1h',
#     'prob_rime:p',
#     'hours_since_forecast',
#     'direct_rad_1h:J',
#     'direct_rad:W',
#     'hour_sin',
#     'visibility:m_lag_forward_1h',
#     'sun_elevation:d',
#     'observed_or_estimated',
#     'clear_sky_rad:W'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8724de50>,
#    'memory_size': 4221,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'bagged_info': {'child_model_type': 'LGBModel',
#     'num_child_models': 4,
#     'child_model_names': ['S1F2', 'S1F1', 'S2F1', 'S2F2'],
#     '_n_repeats': 2,
#     '_k_per_n_repeat': [2, 2],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': True,
#     'max_memory_size': 81229720,
#     'min_memory_size': 20319926,
#     'child_hyperparameters': {'learning_rate': 0.02,
#      'extra_trees': True,
#      'feature_fraction': 0.8,
#      'min_data_in_leaf': 3,
#      'num_leaves': 21},
#     'child_hyperparameters_fit': {'num_boost_round': 9997},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F2': {'name': 'S1F2',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 46.821921586990356,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 15.07366156578064,
#      'val_score': -164.10679982812445,
#      'hyperparameters': {'learning_rate': 0.02,
#       'extra_trees': True,
#       'feature_fraction': 0.8,
#       'min_data_in_leaf': 3,
#       'num_leaves': 21},
#      'hyperparameters_fit': {'num_boost_round': 10000},
#      'hyperparameters_nondefault': ['extra_trees',
#       'feature_fraction',
#       'learning_rate',
#       'min_data_in_leaf',
#       'num_leaves'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8724ed90>,
#      'memory_size': 20315662,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S1F1': {'name': 'S1F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 49.24910640716553,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 14.462647438049316,
#      'val_score': -165.55886189725422,
#      'hyperparameters': {'learning_rate': 0.02,
#       'extra_trees': True,
#       'feature_fraction': 0.8,
#       'min_data_in_leaf': 3,
#       'num_leaves': 21},
#      'hyperparameters_fit': {'num_boost_round': 9991},
#      'hyperparameters_nondefault': ['extra_trees',
#       'feature_fraction',
#       'learning_rate',
#       'min_data_in_leaf',
#       'num_leaves'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba82941ad0>,
#      'memory_size': 20292548,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F1': {'name': 'S2F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 39.54264497756958,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 13.566699028015137,
#      'val_score': -164.46766279659866,
#      'hyperparameters': {'learning_rate': 0.02,
#       'extra_trees': True,
#       'feature_fraction': 0.8,
#       'min_data_in_leaf': 3,
#       'num_leaves': 21},
#      'hyperparameters_fit': {'num_boost_round': 9999},
#      'hyperparameters_nondefault': ['extra_trees',
#       'feature_fraction',
#       'learning_rate',
#       'min_data_in_leaf',
#       'num_leaves'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba82909d90>,
#      'memory_size': 20315705,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F2': {'name': 'S2F2',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 39.59732627868652,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 13.795016765594482,
#      'val_score': -164.63297208915958,
#      'hyperparameters': {'learning_rate': 0.02,
#       'extra_trees': True,
#       'feature_fraction': 0.8,
#       'min_data_in_leaf': 3,
#       'num_leaves': 21},
#      'hyperparameters_fit': {'num_boost_round': 9998},
#      'hyperparameters_nondefault': ['extra_trees',
#       'feature_fraction',
#       'learning_rate',
#       'min_data_in_leaf',
#       'num_leaves'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1badc07a190>,
#      'memory_size': 20301584,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True}}},
#   'CatBoost_BAG_L1': {'name': 'CatBoost_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'regression',
#    'eval_metric': 'mean_absolute_error',
#    'stopping_metric': 'mean_absolute_error',
#    'fit_time': 959.5253760814667,
#    'num_classes': None,
#    'quantile_levels': None,
#    'predict_time': 0.3087575435638428,
#    'val_score': -96.26574601542205,
#    'hyperparameters': {'use_orig_features': True,
#     'max_base_models': 25,
#     'max_base_models_per_type': 5,
#     'save_bag_folds': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 58,
#    'features': ['is_in_shadow:idx',
#     'snow_melt_10min:mm',
#     'dew_point_2m:K',
#     'cloud_base_agl:m',
#     'fresh_snow_3h:cm',
#     'fresh_snow_6h:cm',
#     'month_sin',
#     'clear_sky_energy_1h:J_lag_forward_1h',
#     'clear_sky_energy_1h:J',
#     'fresh_snow_24h:cm',
#     'month_cos',
#     'diffuse_rad:W_lag_forward_1h',
#     'air_density_2m:kgm3',
#     'msl_pressure:hPa',
#     'fresh_snow_1h:cm',
#     'direct_rad_1h:J_lag_forward_1h',
#     'snow_water:kgm2',
#     'direct_rad:W_lag_forward_1h',
#     'pressure_100m:hPa',
#     'is_in_shadow:idx_lag_forward_1h',
#     'diffuse_rad:W',
#     'sun_azimuth:d',
#     'fresh_snow_12h:cm',
#     'wind_speed_w_1000hPa:ms',
#     'pressure_50m:hPa',
#     'wind_speed_10m:ms',
#     'diffuse_rad_1h:J',
#     'absolute_humidity_2m:gm3',
#     'precip_type_5min:idx',
#     'precip_5min:mm',
#     'ceiling_height_agl:m',
#     'rain_water:kgm2',
#     'hour_cos',
#     'total_cloud_cover:p_lag_forward_1h',
#     'wind_speed_v_10m:ms',
#     'effective_cloud_cover:p',
#     'super_cooled_liquid_water:kgm2',
#     'day-of-year',
#     'is_day:idx',
#     'wind_speed_u_10m:ms',
#     't_1000hPa:K',
#     'relative_humidity_1000hPa:p',
#     'clear_sky_rad:W_lag_forward_1h',
#     'dew_or_rime:idx',
#     'sfc_pressure:hPa',
#     'snow_depth:cm',
#     'total_cloud_cover:p',
#     'visibility:m',
#     'effective_cloud_cover:p_lag_forward_1h',
#     'prob_rime:p',
#     'hours_since_forecast',
#     'direct_rad_1h:J',
#     'direct_rad:W',
#     'hour_sin',
#     'visibility:m_lag_forward_1h',
#     'sun_elevation:d',
#     'observed_or_estimated',
#     'clear_sky_rad:W'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba9cc4d8d0>,
#    'memory_size': 4222,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'bagged_info': {'child_model_type': 'CatBoostModel',
#     'num_child_models': 4,
#     'child_model_names': ['S1F1', 'S1F2', 'S2F2', 'S2F1'],
#     '_n_repeats': 2,
#     '_k_per_n_repeat': [2, 2],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': True,
#     'max_memory_size': 43345642,
#     'min_memory_size': 10845451,
#     'child_hyperparameters': {'iterations': 10000,
#      'learning_rate': 0.05,
#      'random_seed': 0,
#      'allow_writing_files': False,
#      'eval_metric': 'MAE'},
#     'child_hyperparameters_fit': {'iterations': 9992},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'CatBoostModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 490.4524416923523,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.0660712718963623,
#      'val_score': -177.82833589830403,
#      'hyperparameters': {'iterations': 10000,
#       'learning_rate': 0.05,
#       'random_seed': 0,
#       'allow_writing_files': False,
#       'eval_metric': 'MAE'},
#      'hyperparameters_fit': {'iterations': 9989},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8724fb50>,
#      'memory_size': 10831317,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S1F2': {'name': 'S1F2',
#      'model_type': 'CatBoostModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 492.27834129333496,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.10912370681762695,
#      'val_score': -177.9275541280686,
#      'hyperparameters': {'iterations': 10000,
#       'learning_rate': 0.05,
#       'random_seed': 0,
#       'allow_writing_files': False,
#       'eval_metric': 'MAE'},
#      'hyperparameters_fit': {'iterations': 9995},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8268af90>,
#      'memory_size': 10841229,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F2': {'name': 'S2F2',
#      'model_type': 'CatBoostModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 466.40698504447937,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.06783390045166016,
#      'val_score': -176.12170463215634,
#      'hyperparameters': {'iterations': 10000,
#       'learning_rate': 0.05,
#       'random_seed': 0,
#       'allow_writing_files': False,
#       'eval_metric': 'MAE'},
#      'hyperparameters_fit': {'iterations': 9994},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 58,
#      'features': ['direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba8444d010>,
#      'memory_size': 10836485,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F1': {'name': 'S2F1',
#      'model_type': 'CatBoostModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 467.23138403892517,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.06572866439819336,
#      'val_score': -176.995712758361,
#      'hyperparameters': {'iterations': 10000,
#       'learning_rate': 0.05,
#       'random_seed': 0,
#       'allow_writing_files': False,
#       'eval_metric': 'MAE'},
# ...
#       'temperature_scalar': None},
#      'num_features': 64,
#      'features': ['LightGBMXT_BAG_L1',
#       'LightGBMcustom2_BAG_L1',
#       'CatBoost_BAG_L1',
#       'NeuralNetFastAI_custom_BAG_L1',
#       'NeuralNetTorch_BAG_L1',
#       'LightGBMLarge_BAG_L1',
#       'direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba949a1c90>,
#      'memory_size': 3507080,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S1F1': {'name': 'S1F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 13.606717348098755,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.21522164344787598,
#      'val_score': -161.26657200907812,
#      'hyperparameters': {'learning_rate': 0.03,
#       'num_leaves': 128,
#       'feature_fraction': 0.9,
#       'min_data_in_leaf': 5},
#      'hyperparameters_fit': {'num_boost_round': 309},
#      'hyperparameters_nondefault': ['learning_rate',
#       'num_leaves',
#       'feature_fraction',
#       'min_data_in_leaf'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 64,
#      'features': ['LightGBMXT_BAG_L1',
#       'LightGBMcustom2_BAG_L1',
#       'CatBoost_BAG_L1',
#       'NeuralNetFastAI_custom_BAG_L1',
#       'NeuralNetTorch_BAG_L1',
#       'LightGBMLarge_BAG_L1',
#       'direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba94a47910>,
#      'memory_size': 3699814,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F1': {'name': 'S2F1',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 13.25320553779602,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.2156214714050293,
#      'val_score': -162.32333541897418,
#      'hyperparameters': {'learning_rate': 0.03,
#       'num_leaves': 128,
#       'feature_fraction': 0.9,
#       'min_data_in_leaf': 5},
#      'hyperparameters_fit': {'num_boost_round': 283},
#      'hyperparameters_nondefault': ['learning_rate',
#       'num_leaves',
#       'feature_fraction',
#       'min_data_in_leaf'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 64,
#      'features': ['LightGBMXT_BAG_L1',
#       'LightGBMcustom2_BAG_L1',
#       'CatBoost_BAG_L1',
#       'NeuralNetFastAI_custom_BAG_L1',
#       'NeuralNetTorch_BAG_L1',
#       'LightGBMLarge_BAG_L1',
#       'direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba94a43d10>,
#      'memory_size': 3386257,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True},
#     'S2F2': {'name': 'S2F2',
#      'model_type': 'LGBModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 13.80347752571106,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': 0.24098873138427734,
#      'val_score': -161.98875865824886,
#      'hyperparameters': {'learning_rate': 0.03,
#       'num_leaves': 128,
#       'feature_fraction': 0.9,
#       'min_data_in_leaf': 5},
#      'hyperparameters_fit': {'num_boost_round': 323},
#      'hyperparameters_nondefault': ['learning_rate',
#       'num_leaves',
#       'feature_fraction',
#       'min_data_in_leaf'],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 64,
#      'features': ['LightGBMXT_BAG_L1',
#       'LightGBMcustom2_BAG_L1',
#       'CatBoost_BAG_L1',
#       'NeuralNetFastAI_custom_BAG_L1',
#       'NeuralNetTorch_BAG_L1',
#       'LightGBMLarge_BAG_L1',
#       'direct_rad:W',
#       'clear_sky_rad:W',
#       'diffuse_rad:W',
#       'direct_rad_1h:J',
#       'is_in_shadow:idx',
#       'clear_sky_energy_1h:J',
#       'diffuse_rad_1h:J',
#       'is_day:idx',
#       'sun_elevation:d',
#       'ceiling_height_agl:m',
#       'effective_cloud_cover:p',
#       'visibility:m',
#       'total_cloud_cover:p',
#       'air_density_2m:kgm3',
#       'wind_speed_v_10m:ms',
#       'dew_point_2m:K',
#       'wind_speed_u_10m:ms',
#       't_1000hPa:K',
#       'absolute_humidity_2m:gm3',
#       'snow_water:kgm2',
#       'relative_humidity_1000hPa:p',
#       'fresh_snow_24h:cm',
#       'cloud_base_agl:m',
#       'fresh_snow_12h:cm',
#       'snow_depth:cm',
#       'dew_or_rime:idx',
#       'fresh_snow_6h:cm',
#       'super_cooled_liquid_water:kgm2',
#       'fresh_snow_3h:cm',
#       'rain_water:kgm2',
#       'precip_type_5min:idx',
#       'precip_5min:mm',
#       'fresh_snow_1h:cm',
#       'sun_azimuth:d',
#       'msl_pressure:hPa',
#       'pressure_100m:hPa',
#       'pressure_50m:hPa',
#       'sfc_pressure:hPa',
#       'prob_rime:p',
#       'wind_speed_10m:ms',
#       'snow_melt_10min:mm',
#       'wind_speed_w_1000hPa:ms',
#       'observed_or_estimated',
#       'hour_cos',
#       'hour_sin',
#       'month_sin',
#       'month_cos',
#       'day-of-year',
#       'hours_since_forecast',
#       'direct_rad:W_lag_forward_1h',
#       'clear_sky_rad:W_lag_forward_1h',
#       'diffuse_rad:W_lag_forward_1h',
#       'direct_rad_1h:J_lag_forward_1h',
#       'is_in_shadow:idx_lag_forward_1h',
#       'clear_sky_energy_1h:J_lag_forward_1h',
#       'effective_cloud_cover:p_lag_forward_1h',
#       'visibility:m_lag_forward_1h',
#       'total_cloud_cover:p_lag_forward_1h'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1bb5f9d4d50>,
#      'memory_size': 3867986,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True}}},
#   'WeightedEnsemble_L3': {'name': 'WeightedEnsemble_L3',
#    'model_type': 'WeightedEnsembleModel',
#    'problem_type': 'regression',
#    'eval_metric': 'mean_absolute_error',
#    'stopping_metric': 'mean_absolute_error',
#    'fit_time': 0.739173412322998,
#    'num_classes': None,
#    'quantile_levels': None,
#    'predict_time': 0.0,
#    'val_score': -78.7728039446139,
#    'hyperparameters': {'use_orig_features': False,
#     'max_base_models': 25,
#     'max_base_models_per_type': 5,
#     'save_bag_folds': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': ['save_bag_folds'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 3,
#    'features': ['LightGBMcustom2_BAG_L2',
#     'NeuralNetTorch_BAG_L2',
#     'LightGBMLarge_BAG_L2'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba94a173d0>,
#    'memory_size': 3994,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'bagged_info': {'child_model_type': 'GreedyWeightedEnsembleModel',
#     'num_child_models': 1,
#     'child_model_names': ['S1F1'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [1],
#     '_random_state': 3,
#     'low_memory': False,
#     'bagged_mode': False,
#     'max_memory_size': 3994,
#     'min_memory_size': 3994,
#     'child_hyperparameters': {'ensemble_size': 100},
#     'child_hyperparameters_fit': {'ensemble_size': 31},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': None,
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None,
#      'drop_unique': False}},
#    'stacker_info': {'num_base_models': 3,
#     'base_model_names': ['LightGBMcustom2_BAG_L2',
#      'NeuralNetTorch_BAG_L2',
#      'LightGBMLarge_BAG_L2']},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'GreedyWeightedEnsembleModel',
#      'problem_type': 'regression',
#      'eval_metric': 'mean_absolute_error',
#      'stopping_metric': 'mean_absolute_error',
#      'fit_time': 0.739173412322998,
#      'num_classes': None,
#      'quantile_levels': None,
#      'predict_time': None,
#      'val_score': None,
#      'hyperparameters': {'ensemble_size': 100},
#      'hyperparameters_fit': {'ensemble_size': 31},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': None,
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None,
#       'drop_unique': False},
#      'num_features': 3,
#      'features': ['LightGBMcustom2_BAG_L2',
#       'NeuralNetTorch_BAG_L2',
#       'LightGBMLarge_BAG_L2'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1ba94a141d0>,
#      'memory_size': 6559,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'model_weights': {'LightGBMcustom2_BAG_L2': 0.0967741935483871,
#       'NeuralNetTorch_BAG_L2': 0.7419354838709677,
#       'LightGBMLarge_BAG_L2': 0.16129032258064516}}}}},
#  'model_info_failures': {}}

# %% [markdown]
# # Make predictions

# %%
# Assuming you have defined WEATHER_FEATURES, TEST_COLUMNS_TO_KEEP, and other functions previously

def make_predictions(df_test_pred, location):
    eval_model = TabularPredictor.load(f"autogluon_models/test_model{location}", require_version_match=False)
    preds = eval_model.predict(df_test_pred)
    return preds

# %% [markdown]
# ## Evaluate locally

# %%
import matplotlib.pyplot as plt


def evaluate_model_locally(location, scalers):
    # Load the test data
    target_df = pd.read_parquet(f"data/{location}/train_targets.parquet")
    
    # Make predictions
    # filter x_validate to only include values from location
    pred_dataset = combined_df_validation[combined_df_validation["location"] == location]
    pred_dataset.reset_index(inplace=True)

    preds = make_predictions(pred_dataset.drop("pv_measurement", axis=1), location)[-720:]
    target = target_df.tail(720)["pv_measurement"].to_numpy()
    
    differences = preds - target
    # Count predictions lower than the actual
    lower_predictions = (differences < 0) & (target != 0)
    # Count predictions higher than the actual
    higher_predictions = (differences > 0) & (target != 0)

    # Biggest misreads
    absolute_differences = abs(differences)
    max_diff_index = absolute_differences.argmax()  # Index of the biggest difference
    # max_diff_value = absolute_differences[max_diff_index]  # Value of the biggest difference
    print(f"Number of predictions that are a lower value than the actual, given that the actual is not 0: {lower_predictions.sum()}")
    print(f"Number of predictions that are larger than the target, given that the target is not 0: {higher_predictions.sum()}")
    # print(f"The biggest misread is at index {max_diff_index} with a difference of {max_diff_value}")
    
    index = target_df.index[-720:]
    print(f'location: {location}')
    # Plotting
    plt.figure(figsize=(60,6))
    plt.plot(index, target, label="Target")
    plt.plot(index, preds, label="Predictions")
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.title('Target vs Predictions')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

for loc in locations:
    # evaluate_model_locally(loc, scalers)
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\autoML_mathias copy.ipynb Cell 16 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=42'>43</a>     plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=44'>45</a> for loc in locations:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=45'>46</a>     evaluate_model_locally(loc, scalers)
#
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\autoML_mathias copy.ipynb Cell 16 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> target_df = pd.read_parquet(f"data/{location}/train_targets.parquet")
#       <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> # Make predictions
#       <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> # filter x_validate to only include values from location
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> pred_dataset = combined_df_validation[combined_df_validation["location"] == location]
#      <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> pred_dataset.reset_index(inplace=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/Bruker/Documents/Notater/NTNU/Maskinl%C3%A6ring/Group%20assignment/TDT4173-project/autoML_mathias%20copy.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a> preds = make_predictions(pred_dataset.drop("pv_measurement", axis=1), location)[-720:]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ## Submit to csv 1

# %%
df_submission = pd.read_csv("data/test.csv")

for index, location in enumerate(locations): 
    preds = make_predictions(combined_df_test[index], location)

    # Assign the predictions to df_submission for the current location
    mask = df_submission["location"] == location
    # Add a check to make sure the lengths match
    if len(preds) != mask.sum():
        raise ValueError(f"Mismatch in length of predictions and submission entries for location {location}.")

    df_submission.loc[mask, "prediction"] = preds.to_numpy()


# Save the results to a new submission file
df_submission[["id", "prediction"]].to_csv("predictions/autogluon-Erik-2.csv", index=False)
# Out:
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# C:\Users\Bruker\AppData\Local\Temp\ipykernel_8036\1610722188.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 3.26064229e-01  3.29622805e-01  3.16377670e-01  6.61992645e+01
#   2.73377197e+02  9.33064331e+02  1.90072107e+03  2.62012231e+03
#   2.20494019e+03  1.95720020e+03  2.23578467e+03  2.63897070e+03
#   2.06063354e+03  2.37311475e+03  1.92661633e+03  1.55313232e+03
#   1.25084265e+03  5.82363647e+02  2.10676605e+02  2.09741020e+01
#   4.27170575e-01  2.79213309e-01  1.63727909e-01  1.72718719e-01
#   1.83554828e-01  2.20516026e-01  7.43460000e-01  2.21535156e+02
#   7.09364502e+02  1.35995569e+03  2.26846655e+03  3.18522095e+03
#   3.82184595e+03  3.98609131e+03  4.09398511e+03  4.10833740e+03
#   3.99500439e+03  3.81359399e+03  3.52513965e+03  2.76108643e+03
#   1.77020728e+03  9.14916870e+02  4.83566528e+02  1.20561432e+02
#   1.46063161e+00  5.62549233e-01  1.59028918e-01  1.76297098e-01
#   1.99256003e-01  3.69552612e-01  3.09101353e+01  2.62349915e+02
#   7.06975891e+02  1.46252991e+03  2.53451025e+03  3.56810181e+03
#   4.27992432e+03  4.66588428e+03  4.63520166e+03  4.34940527e+03
#   4.30784717e+03  3.80984912e+03  2.77254834e+03  1.87360034e+03
#   1.37031067e+03  8.52805603e+02  4.55244232e+02  1.97939651e+02
#   2.42898417e+00  2.32204869e-01  2.41198301e-01  8.47508430e-01
#   1.54148579e-01  1.06090105e+00  2.85882626e+01  1.55708221e+02
#   5.75836426e+02  1.42046021e+03  2.57285547e+03  3.56252881e+03
#   3.50286572e+03  3.37801758e+03  3.45073120e+03  3.16166943e+03
#   3.11594751e+03  3.57444067e+03  3.33273315e+03  2.70283911e+03
#   1.56944946e+03  6.77085022e+02  3.63752167e+02  1.52223984e+02
#   5.10547304e+00  3.02889436e-01  3.47539008e-01  1.74294814e-01
#   2.82742739e-01  2.03862458e-01  5.21369514e+01  2.67451202e+02
#   6.25648010e+02  1.57201270e+03  2.85773193e+03  3.50110645e+03
#   4.37255273e+03  4.56215332e+03  4.79660840e+03  4.72558594e+03
#   4.50436279e+03  4.03542773e+03  3.48229736e+03  2.96887842e+03
#   1.95923975e+03  1.07512646e+03  4.92395203e+02  2.54872406e+02
#   3.62302055e+01  3.23892921e-01  9.67445225e-02 -8.40481520e-02
#   3.70627046e-01  8.85209680e-01  5.61186523e+01  2.42387329e+02
#   6.86477783e+02  1.59821545e+03  2.56131860e+03  3.79237109e+03
#   4.20907129e+03  3.92844434e+03  3.85887793e+03  3.19063062e+03
#   3.52126123e+03  3.56843701e+03  3.12236792e+03  2.02417639e+03
#   1.54707922e+03  9.80711182e+02  5.04147888e+02  2.28057785e+02
#   3.64516411e+01 -9.19229686e-02  1.80492327e-01  2.55152225e-01
#   3.20262074e-01  6.36576116e-01  7.14826584e+01  2.80962341e+02
#   7.45438660e+02  1.69318921e+03  2.63534229e+03  3.72647803e+03
#   4.06366772e+03  4.32041992e+03  4.20003516e+03  4.02506250e+03
#   3.82083325e+03  3.66289307e+03  3.07516553e+03  2.26442114e+03
#   1.66340930e+03  8.73457153e+02  4.40417603e+02  1.82856964e+02
#   1.88341198e+01  4.46690977e-01  2.80944109e-01  1.33569166e-01
#   1.34494349e-01  9.93736610e-02  1.34447374e+01  6.98431854e+01
#   1.75130997e+02  2.55604675e+02  3.34511017e+02  4.88916595e+02
#   5.75980591e+02  7.42544434e+02  7.83039124e+02  1.23230945e+03
#   1.88440894e+03  1.68180127e+03  2.00427588e+03  1.61001208e+03
#   8.08131958e+02  4.56565765e+02  2.92930725e+02  1.74134781e+02
#   4.02613716e+01  3.93068075e-01  3.71299684e-01  3.57196450e-01
#   3.18175256e-01  4.30887640e-01  5.38648262e+01  1.51474686e+02
#   3.52997772e+02  8.01431885e+02  1.32256226e+03  1.86040344e+03
#   1.67546252e+03  2.02298804e+03  2.57014795e+03  1.90637598e+03
#   2.33507764e+03  2.49428247e+03  2.08197827e+03  1.13904187e+03
#   7.62731506e+02  4.43678558e+02  1.92617645e+02  6.67825546e+01
#   5.91524744e+00 -6.28270656e-02  1.38342246e-01  2.25374907e-01
#   1.75312757e-01  1.94834709e-01  7.00650177e+01  1.50421692e+02
#   2.75064941e+02  3.85863770e+02  8.73985474e+02  1.47515796e+03
#   1.81547339e+03  1.61893481e+03  1.53752563e+03  1.47871423e+03
#   1.36647119e+03  1.09575195e+03  1.01579395e+03  7.82213623e+02
#   5.43810608e+02  3.88251648e+02  2.60897034e+02  1.23002525e+02
#   9.37593937e+00  3.64228189e-01  3.87943029e-01  3.43435526e-01
#   2.88932115e-01  1.89054877e-01  3.70000305e+01  1.13836288e+02
#   2.82309540e+02  7.77041992e+02  1.34355017e+03  1.50610352e+03
#   1.53134338e+03  1.35921399e+03  1.73634473e+03  1.47058728e+03
#   1.97931689e+03  2.31973926e+03  2.42566333e+03  2.09889478e+03
#   1.29021655e+03  8.12289856e+02  4.04485382e+02  2.06126358e+02
#   5.34909134e+01  3.34232211e-01  3.06327820e-01  2.60483027e-01
#   2.97151744e-01  3.58730137e-01  8.19015121e+01  1.42747253e+02
#   3.13856567e+02  5.33384399e+02  8.38504883e+02  9.38870483e+02
#   1.12796350e+03  9.31104614e+02  1.36296802e+03  1.02937769e+03
#   8.48095093e+02  7.21961853e+02  7.16071411e+02  5.87194763e+02
#   5.10599579e+02  3.13115967e+02  1.74342072e+02  8.66476212e+01
#   4.97216463e+00  3.34192365e-02 -9.76365134e-02  4.60919887e-01
#   2.29468048e-01  7.51020312e-01  6.08904572e+01  1.53795532e+02
#   4.23203491e+02  8.50082764e+02  1.07724915e+03  1.26138831e+03
#   1.45739697e+03  1.91452295e+03  2.03861560e+03  1.59999695e+03
#   1.43695154e+03  1.45767725e+03  1.60734814e+03  1.42007239e+03
#   1.26947717e+03  6.47217163e+02  3.20433777e+02  1.68470551e+02
#   3.79226227e+01  3.29337120e-01  1.95405111e-01  1.60936579e-01
#   1.70978427e-01  1.93582356e+00  6.86884766e+01  1.78922379e+02
#   3.68167145e+02  6.59190186e+02  1.23354443e+03  1.77088831e+03
#   1.86078748e+03  2.08870776e+03  1.89856506e+03  2.04532300e+03
#   1.65950427e+03  1.52706140e+03  1.31513818e+03  9.72378784e+02
#   6.99349915e+02  4.14829590e+02  1.95532013e+02  7.39959335e+01
#   1.08743439e+01  1.69852346e-01  1.70493275e-01  1.65308580e-01
#   9.68281031e-02  2.61128497e+00  3.57144890e+01  1.05982285e+02
#   2.32417343e+02  4.88667511e+02  7.29522766e+02  9.44824402e+02
#   1.15177527e+03  1.25393567e+03  1.22031714e+03  1.33977490e+03
#   1.27051367e+03  1.13447229e+03  1.18805884e+03  9.88810669e+02
#   6.77717773e+02  3.53053894e+02  2.14748260e+02  1.17131371e+02
#   3.82429047e+01  2.25303173e-01  1.90459549e-01  1.61634132e-01
#   1.51622429e-01  5.67338848e+00  6.73362656e+01  1.72318375e+02
#   3.10484497e+02  5.51972229e+02  8.68244995e+02  1.02625208e+03
#   1.47634351e+03  1.35802991e+03  1.46355261e+03  1.89896704e+03
#   1.79650708e+03  1.49047253e+03  1.35684155e+03  9.68642395e+02
#   8.73590454e+02  4.83644165e+02  2.36283585e+02  9.44328613e+01
#   8.47196960e+00  1.26892805e-01  1.25199065e-01  9.35593992e-02
#   1.38905421e-01  5.60725927e+00  7.94970627e+01  1.61225067e+02
#   3.13986816e+02  4.85851746e+02  5.74933838e+02  7.54737610e+02
#   9.91886414e+02  1.20479004e+03  1.36696106e+03  1.44716223e+03
#   1.46457007e+03  1.23652771e+03  1.31040698e+03  9.26277344e+02
#   9.21859680e+02  8.89690308e+02  4.56302429e+02  2.25188477e+02
#   1.01921722e+02  1.13328302e+00 -2.82892287e-01  3.45432550e-01
#   8.58954668e-01  3.56512184e+01  1.90466568e+02  4.35412415e+02
#   1.07441235e+03  2.11229883e+03  3.33027856e+03  4.20061572e+03
#   4.72500586e+03  5.08892871e+03  4.91990967e+03  4.82149805e+03
#   4.66694336e+03  4.08087671e+03  3.56606421e+03  2.89491528e+03
#   2.14362988e+03  1.34950049e+03  7.34266907e+02  4.51036438e+02
#   2.19485077e+02  1.57306089e+01  5.30144930e-01  2.00471491e-01
#   3.44498754e-01  2.02684746e+01  1.72069046e+02  3.63428253e+02
#   8.72825317e+02  1.57219714e+03  2.51785938e+03  3.47015576e+03
#   4.24589160e+03  4.52393945e+03  3.67660034e+03  1.96728308e+03
#   1.09285449e+03  8.64055298e+02  1.10089441e+03  1.25061780e+03
#   9.98474487e+02  6.61700745e+02  3.34610657e+02  2.38374451e+02
#   1.30144012e+02  6.59966421e+00  4.15380865e-01  1.21220917e-01
#   8.49830732e-02  6.58095741e+00  7.93701782e+01  1.77765305e+02
#   4.24844879e+02  1.19230884e+03  2.18117334e+03  3.07164331e+03
#   4.19354395e+03  4.39730859e+03  4.22332080e+03  4.38737793e+03
#   4.32533447e+03  3.98172021e+03  3.56156494e+03  2.83593921e+03
#   2.09686694e+03  1.34445398e+03  7.02007690e+02  3.82281219e+02
#   1.67639725e+02  7.44125652e+00  3.64863724e-01  2.66093433e-01
#   4.53300893e-01  1.04748669e+01  1.47965820e+02  3.33086823e+02
#   7.97616394e+02  1.73712439e+03  2.62939404e+03  3.53637793e+03
#   4.31306494e+03  4.78447559e+03  4.92131836e+03  4.90078955e+03
#   4.47770947e+03  4.13870410e+03  3.59270068e+03  2.85527856e+03
#   2.15356250e+03  1.39746570e+03  7.58383301e+02  4.52369568e+02
#   2.14218750e+02  6.23376036e+00  3.15289199e-01  2.10998088e-01
#   4.05090511e-01  1.10417538e+01  1.33532227e+02  3.50486267e+02
#   8.18387695e+02  1.63879077e+03  2.42828125e+03  3.71048291e+03
#   4.34999951e+03  4.70606787e+03  4.63607764e+03  3.59904834e+03
#   3.36452954e+03  3.23493457e+03  2.26314404e+03  1.97066858e+03
#   1.40669275e+03  7.41140076e+02  4.08123993e+02  2.35864243e+02
#   1.02714958e+02  5.50019562e-01  6.41790569e-01  4.11745697e-01
#  -2.39964262e-01  7.27856922e+00  8.24272461e+01  1.42521774e+02
#   3.21899475e+02  5.56517700e+02  9.07168701e+02  1.02960767e+03
#   1.04580469e+03  1.04182410e+03  1.82681299e+03  3.58287183e+03
#   3.90914624e+03  3.55207812e+03  3.09719531e+03  2.58114941e+03
#   1.72274780e+03  1.17662317e+03  6.53123962e+02  3.70240570e+02
#   1.58690536e+02  1.72497559e+00  1.41352272e+00  6.63198650e-01
#  -4.39656675e-01  5.96747637e+00  5.48905334e+01  1.14012924e+02
#   9.81663437e+01  2.21048370e+02  4.57273254e+02  7.91039124e+02
#   1.01605475e+03  1.22288110e+03  1.32947131e+03  1.31983228e+03
#   1.42707837e+03  2.28742847e+03  2.20930347e+03  2.07620923e+03
#   1.27765942e+03  7.56617310e+02  3.73959778e+02  1.57830994e+02
#   7.74324112e+01  2.68072319e+00  3.17855597e-01  7.61393070e-01
#   5.73056459e-01  3.80387993e+01  1.83543823e+02  3.71433685e+02
#   8.70180908e+02  1.81095044e+03  2.80844531e+03  3.69215942e+03
#   4.15084863e+03  4.37745117e+03  4.56759326e+03  4.39778809e+03
#   3.82977612e+03  2.92756494e+03  2.33121899e+03  1.93879846e+03
#   1.50103308e+03  9.58559082e+02  4.67084534e+02  2.92060974e+02
#   1.50234421e+02  1.81480110e+00  9.00989294e-01  2.08872914e-01
#  -1.74977317e-01  3.66199923e+00  1.37146484e+02  3.30242493e+02
#   7.85678345e+02  1.63453931e+03  2.44960059e+03  3.49319775e+03
#   4.18529102e+03  4.46857227e+03  4.44366992e+03  4.57029688e+03
#   4.28653711e+03  3.83022363e+03  2.82541211e+03  1.88795874e+03
#   1.33673816e+03  8.40132812e+02  5.38407654e+02  2.68738525e+02
#   1.09122437e+02  6.46803761e+00  1.11558771e+00  9.38113987e-01
#   3.27321231e-01  1.71561947e+01  1.34148865e+02  2.19445740e+02
#   3.12227264e+02  4.09752686e+02  5.91472961e+02  6.67121338e+02
#   9.15690247e+02  1.37597021e+03  1.04476343e+03  9.22493530e+02
#   1.20023376e+03  8.08019653e+02  8.50340515e+02  6.62603333e+02
#   5.15102478e+02  3.22537506e+02  2.11288330e+02  8.46340637e+01
#   2.98826218e+01  1.04575408e+00  1.87526017e-01  6.58805490e-01
#  -1.66717410e-01  3.49382973e+00  3.36937790e+01  6.21608162e+01
#   1.43274307e+02  1.92334518e+02  3.22430573e+02  5.66037964e+02
#   5.24584290e+02  5.01930603e+02  4.93660919e+02  4.94973450e+02
#   7.14473633e+02  8.23433594e+02  7.35115845e+02  6.94656799e+02
#   6.42428223e+02  4.70898560e+02  2.41813263e+02  1.70115463e+02
#   6.42609406e+01  3.09107232e+00  5.04073441e-01  7.75687039e-01
#   2.12240666e-01  9.39773560e+00  1.10471390e+02  2.24680267e+02
#   5.27029053e+02  1.23361230e+03  2.10019165e+03  2.63184961e+03
#   3.69601416e+03  3.99261768e+03  4.01993994e+03  3.90195728e+03
#   3.68419336e+03  3.03620435e+03  2.16033179e+03  1.61428870e+03
#   1.13070166e+03  6.65264465e+02  4.07707520e+02  2.60819061e+02
#   1.11602928e+02  1.58530724e+00  1.01481223e+00  1.48144710e+00
#   7.33556628e-01  1.38332882e+01  6.86163559e+01  1.73711090e+02
#   1.94658722e+02  2.93411011e+02  3.18246155e+02  6.49387817e+02
#   1.47177002e+03  2.06981201e+03  2.68801489e+03  3.12839062e+03
#   2.73572461e+03  1.75747827e+03  1.20278003e+03  9.16801025e+02
#   7.15998352e+02  5.39619263e+02  3.57010345e+02  1.84636932e+02
#   7.90776520e+01  2.20511460e+00  4.72736239e-01  1.42283707e+01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_submission.loc[mask, "prediction"] = preds.to_numpy()
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# c:\Users\Bruker\Documents\Notater\NTNU\Maskinlæring\Group assignment\TDT4173-project\.venv\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
